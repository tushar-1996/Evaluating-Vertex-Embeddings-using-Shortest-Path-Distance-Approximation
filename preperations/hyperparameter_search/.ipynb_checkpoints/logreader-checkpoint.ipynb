# %%
import re
with open('optimization.txt', 'r') as file:
    data = file.read()

# %%
data = str(data)

# %%
data
# Out:
# "Params for Embeddings:  {'layer_config': [403, 128]}  with embedding type:  sdne\nEmbedded training set size: 1022640\nEmbedded test set size: 109978\nTrain test split summary: \n Train X shape: (1022640, 2, 128, 1) Train y shape: (1022640,) \n Test X shape: (109978, 2, 128, 1) Test y shape: (109978,)\n\n\n\n\nEpoch 1/15\n22371/22371 - 68s - loss: 0.6481 - mae: 0.6275 - val_loss: 0.7682 - val_mae: 0.6825\nEpoch 2/15\n22371/22371 - 67s - loss: 0.6118 - mae: 0.6005 - val_loss: 0.7465 - val_mae: 0.6641\nEpoch 3/15\n22371/22371 - 67s - loss: 0.5718 - mae: 0.5616 - val_loss: 0.7322 - val_mae: 0.6388\nEpoch 4/15\n22371/22371 - 58s - loss: 0.5234 - mae: 0.5256 - val_loss: 0.6984 - val_mae: 0.6227\nEpoch 5/15\n22371/22371 - 58s - loss: 0.4870 - mae: 0.5010 - val_loss: 0.7382 - val_mae: 0.6169\nEpoch 6/15\n22371/22371 - 58s - loss: 0.4569 - mae: 0.4806 - val_loss: 0.7115 - val_mae: 0.6166\nEpoch 7/15\n22371/22371 - 68s - loss: 0.4360 - mae: 0.4676 - val_loss: 0.6844 - val_mae: 0.6082\nEpoch 8/15\n22371/22371 - 67s - loss: 0.4195 - mae: 0.4558 - val_loss: 0.6712 - val_mae: 0.5921\nEpoch 9/15\n22371/22371 - 58s - loss: 0.4117 - mae: 0.4501 - val_loss: 0.7011 - val_mae: 0.6140\nEpoch 10/15\n22371/22371 - 68s - loss: 0.4030 - mae: 0.4438 - val_loss: 0.7409 - val_mae: 0.6027\nEpoch 11/15\n22371/22371 - 67s - loss: 0.3969 - mae: 0.4387 - val_loss: 0.7585 - val_mae: 0.6202\nEpoch 12/15\n22371/22371 - 68s - loss: 0.3917 - mae: 0.4354 - val_loss: 0.7932 - val_mae: 0.6252\nEpoch 13/15\n22371/22371 - 58s - loss: 0.3837 - mae: 0.4292 - val_loss: 0.7318 - val_mae: 0.6196\nEpoch 14/15\n22371/22371 - 58s - loss: 0.3808 - mae: 0.4272 - val_loss: 0.7279 - val_mae: 0.6053\nEpoch 15/15\n22371/22371 - 68s - loss: 0.3765 - mae: 0.4236 - val_loss: 0.6998 - val_mae: 0.6073\n\n\nRMSE: 0.6860781526585743 MAE: 0.3789576097037589 \nSummary: \nNodes: 4039 Edges: 88234 Train size: 1022640 Test size: 109978\nAccuracy: 0.662605\nPaths: \t\t [2 3 4 5 6]\nPrecision: \t [0.         0.9325354  0.56363825 0.5759182  0.61576041 0.72380952]\nRecall: \t [0.         0.60809544 0.77395872 0.71170181 0.41730243 0.04542738]\n/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.\n  _warn_prf(average, modifier, msg_start, len(result))\nF1 score: \t [0.         0.73615367 0.65226335 0.6366506  0.4974689  0.08548931]\nParams for Embeddings:  {'layer_config': [403, 201, 128]}  with embedding type:  sdne\nEmbedded training set size: 1022640\nEmbedded test set size: 109978\nTrain test split summary: \n Train X shape: (1022640, 2, 128, 1) Train y shape: (1022640,) \n Test X shape: (109978, 2, 128, 1) Test y shape: (109978,)\n\n\n\n\nEpoch 1/15\n22371/22371 - 58s - loss: 0.6712 - mae: 0.6422 - val_loss: 0.7834 - val_mae: 0.6917\nEpoch 2/15\n22371/22371 - 68s - loss: 0.6406 - mae: 0.6226 - val_loss: 0.7775 - val_mae: 0.6880\nEpoch 3/15\n22371/22371 - 67s - loss: 0.6309 - mae: 0.6137 - val_loss: 0.7874 - val_mae: 0.6814\nEpoch 4/15\n22371/22371 - 69s - loss: 0.6124 - mae: 0.5954 - val_loss: 0.7439 - val_mae: 0.6603\nEpoch 5/15\n22371/22371 - 68s - loss: 0.5839 - mae: 0.5738 - val_loss: 0.7255 - val_mae: 0.6541\nEpoch 6/15\n22371/22371 - 58s - loss: 0.5594 - mae: 0.5555 - val_loss: 0.7182 - val_mae: 0.6246\nEpoch 7/15\n22371/22371 - 57s - loss: 0.5417 - mae: 0.5424 - val_loss: 0.7202 - val_mae: 0.6454\nEpoch 8/15\n22371/22371 - 68s - loss: 0.5282 - mae: 0.5327 - val_loss: 0.6932 - val_mae: 0.6367\nEpoch 9/15\n22371/22371 - 68s - loss: 0.5180 - mae: 0.5241 - val_loss: 0.6897 - val_mae: 0.6462\nEpoch 10/15\n22371/22371 - 67s - loss: 0.5078 - mae: 0.5161 - val_loss: 0.7306 - val_mae: 0.6437\nEpoch 11/15\n22371/22371 - 67s - loss: 0.5004 - mae: 0.5102 - val_loss: 0.7511 - val_mae: 0.6458\nEpoch 12/15\n22371/22371 - 67s - loss: 0.4949 - mae: 0.5059 - val_loss: 0.7413 - val_mae: 0.6502\nEpoch 13/15\n22371/22371 - 67s ...

# %%
param_set = "Params for Embeddings: .*'p': (?P<q>\d+\.\d+|\d+).*'q': (?P<p>\d+\.\d+|\d+)"
metrics = ".*RMSE: (?P<rmse>\d+\.\d+|\d+).*MAE: (?P<mae>\d+\.\d+|\d+)"

# %%
maes_rmses= re.findall(metrics, data)
maes = [metrics[1] for metrics in maes_rmses][5:]
print(maes)
q_ps= re.findall(param_set, data)
ps = [params[0] for params in q_ps]
qs = [params[1] for params in q_ps]
print(len(qs), len(ps), len(maes))
# Out:
# ['0.05672952772372657', '0.07771554310862172', '0.08400771063303569', '0.10223862954409063', '0.0901089308770845', '0.08296204695484552', '0.06676789903435232', '0.04102638709560094', '0.05400170943279565', '0.041981123497426755', '0.06496753896233792', '0.07453308843586899', '0.0798614268308207', '0.07622433577624615', '0.0664132826565313', '0.0452908763570896', '0.05952099510811253', '0.06526759897434033', '0.035134299587190165', '0.06670424994089727', '0.06802269544818054', '0.09019985815344887', '0.06915019367509866', '0.07880667042499409', '0.08137991234610559']
# 25 25 25

# %%
import matplotlib.pyplot as plt
import numpy as np

cm = plt.cm.get_cmap('RdYlBu')
maes_np = np.asarray(maes, dtype="float32")

sc= plt.scatter(np.array(ps), np.array(qs), c=maes_np, cmap = cm)
plt.colorbar(sc)
plt.title("Max MAE: "+ max(maes)+ " Min MAE: "+ min(maes))
plt.xlabel("p")
plt.ylabel("q")
plt.show()

# %%
import pandas as pd

df_dict = {"q":[], "p":[], "mae":[]}
for q,p,mae in zip(qs, ps, maes):
    df_dict["q"].append(q)
    df_dict["p"].append(p)
    df_dict["mae"].append(mae)

# %%
df = pd.DataFrame(df_dict)

# %%
df.sort_values(by="mae")
# Out:
#        q     p                   mae
# 18  1.25  1.25  0.035134299587190165
# 7      1  0.75   0.04102638709560094
# 9      2  0.75  0.041981123497426755
# 15   0.1  1.25    0.0452908763570896
# 8   1.25  0.75   0.05400170943279565
# 0    0.1   0.1   0.05672952772372657
# 16  0.75  1.25   0.05952099510811253
# 10   0.1     1   0.06496753896233792
# 17     1  1.25   0.06526759897434033
# 14     2     1    0.0664132826565313
# 19     2  1.25   0.06670424994089727
# 6   0.75  0.75   0.06676789903435232
# 20   0.1     2   0.06802269544818054
# 22     1     2   0.06915019367509866
# 11  0.75     1   0.07453308843586899
# 13  1.25     1   0.07622433577624615
# 1   0.75   0.1   0.07771554310862172
# 23  1.25     2   0.07880667042499409
# 12     1     1    0.0798614268308207
# 24     2     2   0.08137991234610559
# 5    0.1  0.75   0.08296204695484552
# 2      1   0.1   0.08400771063303569
# 4      2   0.1    0.0901089308770845
# 21  0.75     2   0.09019985815344887
# 3   1.25   0.1   0.10223862954409063

# %%
df.to_csv("results_hyperparam_search.csv")
